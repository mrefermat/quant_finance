# %%
# %matplotlib inline
import pandas as pd
import statsmodels.api as sm
import numpy as np
# Out:
# /Users/mrefermat/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import seaborn as sns
import pylab
sns.set(font_scale=3)
pylab.rcParams['figure.figsize'] = (18, 12)

# %%
import quandl as q
token="Us3wFmXGgAj_1cUtHAAR"

# %%
FF=pd.read_csv('FF.csv',parse_dates=['Date'],index_col=0)

# %%
yld=q.get("USTREASURY/YIELD", authtoken=token)

# %%
steeper=(yld['10 YR']-yld['2 YR'])

# %%
lookback=2*250
df = pd.DataFrame()
df['Value Returns Rolling 2 year returns']=pd.Series.rolling(FF.HML,lookback).mean()
df['2-10s Spreads']=steeper
df.dropna().plot(secondary_y='2-10s Spreads',colormap='jet',title='Comparing returns and 2-10s spreads')
