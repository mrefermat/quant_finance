# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from stock_data import *
import seaborn as sns

# %%
import pylab
sns.set(font_scale=3)
sns.set_context("poster")
pylab.rcParams['figure.figsize'] = (18, 12)

# %%
df=pd.DataFrame()
df['Min Vol ETF']=get_stock_adj_price('USMV')
df["Momentum"]=get_stock_adj_price('MTUM')
df['Quality']=get_stock_adj_price('QUAL')
df['Value']=get_stock_adj_price('FNDX')
df['Size']=get_stock_adj_price('VB')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-8f7d522b2be6> in <module>()
#       4 df['Quality']=get_stock_adj_price('QUAL')
#       5 df['Value']=get_stock_adj_price('FNDX')
# ----> 6 df['Size']=get_stock_adj_price('SIZE')
#       7
#
# ~/git/quant_finance/stock_data.py in get_stock_adj_price(ticker)
#       9 def get_stock_adj_price(ticker):
#      10         ts = TimeSeries(key=key, output_format='pandas')
# ---> 11         data, meta_data = ts.get_daily_adjusted(ticker,outputsize='full')
#      12         data.index = pd.to_datetime(data.index)
#      13         return data['5. adjusted close']
#
# ~/anaconda3/lib/python3.6/site-packages/alpha_vantage/alphavantage.py in _format_wrapper(self, *args, **kwargs)
#     173         def _format_wrapper(self, *args, **kwargs):
#     174             call_response, data_key, meta_data_key = func(
# --> 175                 self, *args, **kwargs)
#     176             if 'json' in self.output_format.lower() or 'pandas' \
#     177                     in self.output_format.lower():
#
# ~/anaconda3/lib/python3.6/site-packages/alpha_vantage/alphavantage.py in _call_wrapper(self, *args, **kwargs)
#     158             else:
#     159                 url = '{}&apikey={}'.format(url, self.key)
# --> 160             return self._handle_api_call(url), data_key, meta_data_key
#     161         return _call_wrapper
#     162
#
# ~/anaconda3/lib/python3.6/site-packages/alpha_vantage/alphavantage.py in _retry_wrapper(self, *args, **kwargs)
#      77                 except ValueError as err:
#      78                     error_message = str(err)
# ---> 79             raise ValueError(str(error_message))
#      80         return _retry_wrapper
#      81
#
# ValueError: Thank you for using Alpha Vantage! Please visit https://www.alphavantage.co/premium/ if you would like to have a higher API call volume.

# %%
df['Size']=get_stock_adj_price('VB')

# %%
df.dropna().pct_change().cumsum().plot()

# %%
y=df.dropna().pct_change()

# %%
df.Size.pct_change().tail()
# Out:
# date
# 2018-09-27    0.001109
# 2018-09-28    0.004469
# 2018-10-01   -0.010026
# 2018-10-02   -0.007891
# 2018-10-03    0.006012
# Name: Size, dtype: float64

# %%
x.pct_change().tail()
# Out:
# date
# 2018-09-27    0.000570
# 2018-09-28    0.002125
# 2018-10-01   -0.003030
# 2018-10-02    0.002851
# 2018-10-03   -0.003071
# Name: 5. adjusted close, dtype: float64

# %%
hedged_factor=y.subtract(x.pct_change(),axis=0)

# %%
hedged_factor.dropna()['2017':].cumsum().plot()

# %%
x=get_stock_adj_price('VOO')
x.plot()
