# %%
# %matplotlib inline
import pandas as pd
import statsmodels.api as sm
import numpy as np
# Out:
# /Users/mrefermat/anaconda3/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import seaborn as sns
import pylab
sns.set(font_scale=3)
pylab.rcParams['figure.figsize'] = (24, 18)

# %%
from core import *

# %%
bds=get_bond_time_series()

# %%
bds.cumsum().plot()

# %%
sp=get_sp()

# %%
sp.tail()
# Out:
# Date
# 2019-02-28    2754.86
# 2019-03-31    2803.98
# 2019-04-30    2903.80
# 2019-05-31    2752.08
# 2019-06-30    2744.54
# Freq: M, Name: Value, dtype: float64

# %%
portfolios=pd.DataFrame()
portfolios['Bonds']=bds
portfolios['SP']=sp.pct_change()
portfolios['60/40']=portfolios.Bonds*.4 + portfolios.SP *.6
portfolios['Risk Parity']=calc_risk_parity()

# %%
portfolios.dropna().cumsum().plot()

# %%
calc_risk_parity().plot()

# %%
def get_libor():
    return q.get("ECB/RTD_M_S0_N_C_USL3M_U", authtoken=token)['Percent per annum']

# %%
x=calc_risk_parity()

# %%
full=x+get_libor().ffill()/1200.

# %%
x.plot()
