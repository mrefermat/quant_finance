# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
#import alpha_vantage as av
import seaborn as sns
import numpy as np
import math

# %%
import pylab
sns.set(font_scale=3)
pylab.rcParams['figure.figsize'] = (12, 8)

# %%
range(0,100,1)
# Out:
# range(0, 100)

# %%
m=[]
for i in range(0,100):
    e=[]
    for j in range(0,100):
        e.append((100-i)+j)
    m.append(e)

# %%
df=pd.DataFrame(m)
sns.heatmap(df)

# %%
m=[]
for i in range(-100,100,1):
    e=[]
    for j in range(-100,100,1):
        e.append(-(i/100.)*(j/100.)+.3333*(i/100)**3-1.24*(i/100)-3*(i/100)**2-.25*(j/100)**3+.12341*(j/100)**2-(j/100))
    m.append(e)   
df=pd.DataFrame(m)
#sns.heatmap(df)

# %%
m=[]
for i in range(-100,100,1):
    e=[]
    for j in range(-100,100,1):
        e.append(-(i/100.)*(j/100.)
                 -0.33*(i/100)**3
                 -1.16*(j/100)**3
                 +(j/113)
                 +((100-i)/66))
    m.append(e)   
df=pd.DataFrame(m)
sns.heatmap(df)

# %%
m=[]
for i in range(-100,100,1):
    e=[]
    for j in range(-100,100,1):
        e.append(math.exp(i/100)+math.exp(j/100))
    m.append(e)   
df=pd.DataFrame(m)
sns.heatmap(df)

# %%
# Generate a random correlated bivariate dataset
rs = np.random.RandomState(5)
mean = [0, 0]
cov = [(1, .5), (.5, 1)]
x1, x2 = rs.multivariate_normal(mean, cov, 500).T
x1 = pd.Series(x1, name="$X_1$")
x2 = pd.Series(x2, name="$X_2$")

# Show the joint distribution using kernel density estimation
g = sns.jointplot(x1, x2, kind="kde", height=7, space=0)

# %%
g

# %%
df2 = sns.load_dataset("iris")

# %%
x=df2[['sepal_length', 'petal_length']]

# %%
# Out:
#      sepal_length  petal_length
# 0             5.1           1.4
# 1             4.9           1.4
# 2             4.7           1.3
# 3             4.6           1.5
# 4             5.0           1.4
# 5             5.4           1.7
# 6             4.6           1.4
# 7             5.0           1.5
# 8             4.4           1.4
# 9             4.9           1.5
# 10            5.4           1.5
# 11            4.8           1.6
# 12            4.8           1.4
# 13            4.3           1.1
# 14            5.8           1.2
# 15            5.7           1.5
# 16            5.4           1.3
# 17            5.1           1.4
# 18            5.7           1.7
# 19            5.1           1.5
# 20            5.4           1.7
# 21            5.1           1.5
# 22            4.6           1.0
# 23            5.1           1.7
# 24            4.8           1.9
# 25            5.0           1.6
# 26            5.0           1.6
# 27            5.2           1.5
# ...
